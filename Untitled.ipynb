# %% [markdown]
# Loading the required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import accuracy_score as acc
from sklearn.metrics import make_scorer
from sklearn.dummy import DummyRegressor
from sklearn.dummy import DummyClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn import datasets, linear_model


# %matplotlib inline
import seaborn as sns


df = pd.read_csv("./match.csv", delimiter = ",")
print df.columns
# Out:
# Index([u'match_id', u'start_time', u'duration', u'tower_status_radiant',
#        u'tower_status_dire', u'barracks_status_dire',
#        u'barracks_status_radiant', u'first_blood_time', u'game_mode',
#        u'radiant_win', u'negative_votes', u'positive_votes', u'cluster'],
#       dtype='object')

# %%
dur = df['duration']
data = df.values.T[2]
print data
# Out:
# [2375 2582 2716 ..., 2672 2211 2788]

# %%
plt.figure()
plt.hist(data,bins=100)
#plt.hist(data[(900<data)& (data<4000)], bins=20)
plt.show()

# we can see there are a lot of matches with unoptimal time duration
# the purpose is to remove entries containing matches outside the 20-60 min range

# %%
#plt.hist(data[(900<data)& (data<4000)], bins=20)
data1=data[(1200<dur) & (dur<4500)]
plt.hist(data1, bins=20)
# Out:
# (array([  556.,  1191.,  2216.,  3348.,  4640.,  5361.,  5197.,  5285.,
#          4857.,  3853.,  3733.,  2637.,  2030.,  1546.,  1042.,   693.,
#           524.,   343.,   186.,   128.]),
#  array([ 1201. ,  1365.9,  1530.8,  1695.7,  1860.6,  2025.5,  2190.4,
#          2355.3,  2520.2,  2685.1,  2850. ,  3014.9,  3179.8,  3344.7,
#          3509.6,  3674.5,  3839.4,  4004.3,  4169.2,  4334.1,  4499. ]),
#  <a list of 20 Patch objects>)

# %%
df1=df[(1200<df['duration']) & (df['duration']<4500)]
plt.hist(df1['duration'], bins=20)

# df1 represents the dataset excluding the unwanted matches
# Out:
# (array([  556.,  1191.,  2216.,  3348.,  4640.,  5361.,  5197.,  5285.,
#          4857.,  3853.,  3733.,  2637.,  2030.,  1546.,  1042.,   693.,
#           524.,   343.,   186.,   128.]),
#  array([ 1201. ,  1365.9,  1530.8,  1695.7,  1860.6,  2025.5,  2190.4,
#          2355.3,  2520.2,  2685.1,  2850. ,  3014.9,  3179.8,  3344.7,
#          3509.6,  3674.5,  3839.4,  4004.3,  4169.2,  4334.1,  4499. ]),
#  <a list of 20 Patch objects>)

# %%
x = data1['cluster'].values.reshape((49677,1))
y = data1['radiant_win'].values.reshape((49677,1))
model = LogisticRegression()
model = model.fit(X, Y)
model.score (X, Y)
